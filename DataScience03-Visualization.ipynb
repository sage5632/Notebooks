# %%
# maplitlib으로 차트 그리기
# anscombe의 시각화 강조 주장을 검증
# 일반적인 가정 : 복수의 데이터셋이 통계 수치, 상관관계, 회귀선이 같다면 비슷한 데이터 셋
# anscombe의 주장 : 데이터 시각화 하지 않으면 데이터의 분포를 알기 어렵다.-> 시각화 강조

# 데이터셋 불러오기
import seaborn as sns
# 샘플 데이터 셋 목록
print(sns.get_dataset_names())
# anscombe 데이터셋 불러오기
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# ...

# %%
# 데이터의 서브셋의 갯수 확인
print(anscombe['dataset'].nunique()) # 유니크한 값의 갯수
# Out:
# 4

# %%
# 서브셋 분할
ds1 = anscombe[anscombe['dataset'] == 'I'] # 데이터셋 1
ds2 = anscombe[anscombe['dataset'] == 'II'] # 데이터셋 2
ds3 = anscombe[anscombe['dataset'] == 'III'] # 데이터셋 3
ds4 = anscombe[anscombe['dataset'] == 'IV'] # 데이터셋 4

# %%
ds1.describe() # 데이터셋 1의 기초 통계량
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
ds2.describe() # 데이터셋 2의 기초 통계량
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
import matplotlib.pyplot as plt
# 데이터셋 1 그려보기
# plt.plot(ds1['x'], ds1['y'], 'o')
# plt.plot(ds1['x'], ds2['y'], '*')
plt.plot(ds1['x'], ds1['y'], '^')

# %%
# 데이터셋 2의 그래프
plt.plot(ds2['x'], ds2['y'], 'v',color="purple")

# %%
# %matplotlib inline
# 앤스콤 4분할 그래프 그리기
# 그래프의 기본 틀 : figure
fig = plt.figure(figsize=(12,12))
# 기본틀에 격자 추가
axes1 = fig.add_subplot(2, 2, 1) # 2 X 2 격자의 1번 영역
axes2 = fig.add_subplot(2, 2, 2) # 2 X 2 격자의 2번 영역
axes3 = fig.add_subplot(2, 2, 3) # 2 X 2 격자의 3번 영역
axes4 = fig.add_subplot(2, 2, 4) # 2 X 2 격자의 4번 영역
# 격자에 그래프 그리기
axes1.plot(ds1['x'], ds1['y'], 'o')
axes2.plot(ds2['x'], ds2['y'], '+', color="orange")
axes3.plot(ds3['x'], ds3['y'], '*', color="green")
axes4.plot(ds4['x'], ds4['y'], '^', color="blue")
# 서브플롯에 타이틀 출력
axes1.set_title("Dataset I")
axes2.set_title("Dataset II")
axes3.set_title("Dataset III")
axes4.set_title("Dataset IV")
# 기본 틀(Figure)의 타이틀 추가
fig.suptitle("Anscombe DataSets")
# 레이아웃 조정
fig.tight_layout()
plt.show()

# %%
# mtcars 데이터셋을 이용한 산점도 그래프(Scatter plot)
import pandas as pd
mtcars = pd.read_csv("./data/mtcars.csv") # 헤더가 있고, 구분자가 컴마(,)
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
from IPython.display import display
# EDA
print("Size:", mtcars.shape) # 레코드 32 컬럼 12
# 위쪽 데이터 확인
display(mtcars.head())
display(mtcars.tail())
# Out:
# Size: (32, 12)
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# ...

# %%
# 기초 통계량 확인
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
# mpg(연비) vs wt(중량) -> 산점도 그려보기
plt.scatter(mtcars['wt'], mtcars['mpg'])
plt.xlabel('Weight')
plt.ylabel("Mile Per Gallon")
plt.title("Weight vs MPG")

plt.show()

# %%
# 상관 계수
print("상관계수(wt vs mpg)")
mtcars.corr() # 상관계수 - 모든 수치 변수들 사이의 상관 계수
mtcars['wt'].corr(mtcars['mpg']) # wt 변수와 mpg 변수 사이의 상관관계 -> 역상관 관계
# Out:
# 상관계수(wt vs mpg)
# -0.8676593765172281

# %%
# 상자 그림 (Box Plot)
# plt.boxplot(mtcars['mpg']) : 단일 변수의 상자 그림
plt.boxplot([mtcars['mpg'], mtcars['wt']])
plt.show()

print("mpg 기초 통계량")
display(mtcars['mpg'].describe())
# Out:
# mpg 기초 통계량
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
# 분위수 확인
quartiles = mtcars.quantile([0.25, 0.5, 0.75])
display(quartiles)
# Out:
#          mpg  cyl     disp     hp   drat       wt     qsec   vs   am  gear  \
# 0.25  15.425  4.0  120.825   96.5  3.080  2.58125  16.8925  0.0  0.0   3.0
# 0.50  19.200  6.0  196.300  123.0  3.695  3.32500  17.7100  0.0  0.0   4.0
# 0.75  22.800  8.0  326.000  180.0  3.920  3.61000  18.9000  1.0  1.0   4.0
#
#       carb
# 0.25   2.0
# 0.50   2.0
# 0.75   4.0

# %%
# mpg의 1,3사 분위수
first_quartile = mtcars['mpg'].quantile(0.25) # 1사 분위수
third_quartile = mtcars['mpg'].quantile(0.75) # 3사 분위수
print("1사 분위수 {}, 3사 분위수 {}".format(first_quartile, third_quartile))
# IQR(Inter Quartile Range) : Q3 - Q1
Iqr = third_quartile - first_quartile
print("IQR of mpg:", Iqr)
# Out:
# 1사 분위수 15.425, 3사 분위수 22.8
# IQR of mpg: 7.375

# %%
# mpg의 상단 극단치 경계
# Q3 + IQR * 1.5
border_top = third_quartile + Iqr * 1.5
print("상단 극단치 경계:", border_top)
border_bottom = first_quartile - Iqr * 1.5
print("하단 극단치 경계:", border_bottom)
# Out:
# 상단 극단치 경계: 33.8625
# 하단 극단치 경계: 4.362500000000001

# %%
# mpg가 극단치를 가진 자동차 ?
# mpg가 상단 극단치를 초과한 레코드
mtcars['mpg'] > border_top # Boolean 연산
outliers = mtcars[mtcars['mpg'] > border_top]
print("Outliers")
display(outliers)
# Out:
# Outliers
#              model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1
